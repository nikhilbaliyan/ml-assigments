# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/Titanic-EDA-and-Survival-prediction/master/train.csv')

# %%
# First 5 rows
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# NaN values in 'Survived'
data['Survived'].isnull().sum()
# Out:
# 0

# %% [markdown]
# There is no NaN value in 'Survived'

# %%
#Function for input values to Has_cabin from cabin 
def null(col):
    if pd.isnull(col):
        return 0
    else:
        return 1

# %%
data['Has_cabin'] = data['Cabin'].apply(null)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Has_cabin
# 0      0         A/5 21171   7.2500   NaN        S          0
# 1      0          PC 17599  71.2833   C85        C          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0
# 3      0            113803  53.1000  C123        S          1
# ...

# %% [markdown]
# In the above result 0 means not has cabin and 1 means has cabin

# %%
def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    if title_search:
        return title_search.group(1)
    return ""

# %%
data['Title'] = data['Name'].apply(get_title)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Has_cabin Title
# 0      0         A/5 21171   7.2500   NaN        S          0    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0  Miss
# ...

# %%
#input missing values with fillna()
data.mean()
data.fillna(data.mean())
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Has_cabin Title
# 0      0         A/5 21171   7.2500   NaN        S          0    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0  Miss
# ...

# %%
data['Categorical_age'] = pd.qcut(data['Age'],3,labels = False)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Has_cabin Title  \
# 0      0         A/5 21171   7.2500   NaN        S          0    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0  Miss
# ...

# %%
data['Categorical_fare'] = pd.qcut(data['Fare'],3,labels = [1,2,3])
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Has_cabin Title  \
# 0      0         A/5 21171   7.2500   NaN        S          0    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0  Miss
# ...

# %%
#transforming variables into numeric values using get_dummies

df=pd.get_dummies(data['Sex'])
data1=pd.concat([data,df],axis=1)
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Has_cabin Title  \
# 0      0         A/5 21171   7.2500   NaN        S          0    Mr
# 1      0          PC 17599  71.2833   C85        C          1   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0  Miss
# ...

# %%
#Droping columns Cabin,name,passenger,Grid,Ticket,Age,Fare

data2 = data1.drop(columns=['Cabin','Name','PassengerId','Ticket','Fare','SibSp','Age','Parch'])
data2.head()
# Out:
#    Survived  Pclass     Sex Embarked  Has_cabin Title  Categorical_age  \
# 0         0       3    male        S          0    Mr              0.0
# 1         1       1  female        C          1   Mrs              2.0
# 2         1       3  female        S          0  Miss              1.0
# 3         1       1  female        S          1   Mrs              2.0
# 4         0       3    male        S          0    Mr              2.0
#
#   Categorical_fare  female  male
# 0                1       0     1
# 1                3       1     0
# 2                1       1     0
# 3                3       1     0
# 4                1       0     1

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()

# %%
#now splitting the dataset to train and test
from sklearn.cross_validation import train_test_split

# %%
X =data2.drop(['Sex','Title','Survived','Embarked','Categorical_age','Categorical_fare'],axis=1)
Y = data2['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(X , Y , test_size = 0.30,random_state = 2)

# %%
reg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
reg.score(x_test , y_test)
# Out:
# 0.7686567164179104
